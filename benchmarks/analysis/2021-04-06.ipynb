# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import json

# %matplotlib inline

# %% [markdown]
# # Analysis of results
#
# ## Import of data

# %%
DATE = "2021-04-06"


def import_native_and_bytecode(filename):
    native = []
    bytecode = []
    with open(filename) as f:
        for line in f:
            entry = json.loads(line)
            name_sections = list(entry['name'].split('.'))
            if name_sections[0].endswith('bytecode'):
                name_sections[0] = name_sections[0][:-9]
                entry['name'] = '.'.join(name_sections)
                bytecode.append(entry)
            else:
                native.append(entry)
    return pd.json_normalize(native), pd.json_normalize(bytecode)


def import_just_bytecode(filename):
    data = []
    for line in open(filename):
        entry = json.loads(line)
        name_sections = list(entry['name'].split('.'))
        name_sections[0] = name_sections[0][:-9]
        entry['name'] = '.'.join(name_sections)
        data.append(entry)
    return pd.json_normalize(data)
            
    
cranelift = import_just_bytecode(f'{DATE}/4.11.1+jit+cranelift50.orun.bench')
jit = import_just_bytecode(f'{DATE}/4.11.1+jit.orun.bench')

# %%
cranelift
# Out:
#                                          name  \
# 0                           naive-multilayer.
# 1   imrin_mem_rw.10_000_50_000_20_100_000_000
# 2                            nbody.50_000_000
# 3                       durand-kerner-aberth.
# 4                            fannkuchredux.12
# 5                           qr-decomposition.
# 6                         spectralnorm2.5_500
# 7                           fasta3.25_000_000
# 8                                  kb_no_exc.
# 9                                knucleotide.
# 10                         floyd_warshall.512
# 11                                  revcomp2.
# 12                                     bdd.26
# 13                                       fft.
# 14                 test_decompress.64_524_288
# 15                         sequence_cps.10000
# 16  imrin_mem_rw.10_000_50_000_80_100_000_000
# 17                            binarytrees5.21
# 18                               lexifi-g2pp.
# 19                          fasta6.25_000_000
# 20                thread_ring_lwt_mvar.20_000
# 21                       crout-decomposition.
# 22                 matrix_multiplication.1024
# 23         evolutionary_algorithm.10000_10000
# 24                 chameneos_redux_lwt.600000
# 25                          quicksort.4000000
# 26                           game_of_life.256
# 27                              knucleotide3.
# 28                               test_lwt.200
# 29                         mandelbrot6.16_000
# 30                           levinson-durbin.
# 31              thread_ring_lwt_stream.20_000
# 32                          fannkuchredux2.12
# 33                                        kb.
# 34                      LU_decomposition.1024
#
#                                               command   time_secs  \
# 0          taskset --cpu-list 5 ./naive_multilayer.bc   12.410587
# 1   taskset --cpu-list 5 ./irmin_mem_rw.bc 10_000 ...   20.242394
# 2          taskset --cpu-list 5 ./nbody.bc 50_000_000   94.862960
# 3      taskset --cpu-list 5 ./durand_kerner_aberth.bc    1.143021
# 4          taskset --cpu-list 5 ./fannkuchredux.bc 12  394.706636
# 5          taskset --cpu-list 5 ./qr_decomposition.bc    4.290923
# 6       taskset --cpu-list 5 ./spectralnorm2.bc 5_500   33.703385
# 7         taskset --cpu-list 5 ./fasta3.bc 25_000_000   10.756673
# 8                 taskset --cpu-list 5 ./kb_no_exc.bc    4.258226
# 9               taskset --cpu-list 5 ./knucleotide.bc   60.786151
# 10       taskset --cpu-list 5 ./floyd_warshall.bc 512    5.330353
# 11                 taskset --cpu-list 5 ./revcomp2.bc    2.663806
# 12                   taskset --cpu-list 5 ./bdd.bc 26   10.034514
# 13                      taskset --cpu-list 5 ./fft.bc    6.329975
# 14  taskset --cpu-list 5 ./test_decompress.bc 64 5...   15.497876
# 15       taskset --cpu-list 5 ./sequence_cps.bc 10000    2.886088
# 16  taskset --cpu-list 5 ./irmin_mem_rw.bc 10_000 ...   23.554973
# 17          taskset --cpu-list 5 ./binarytrees5.bc 21    9.731460
# 18                     taskset --cpu-list 5 ./main.bc   37.212973
# 19        taskset --cpu-list 5 ./fasta6.bc 25_000_000    9.877710
# 20  taskset --cpu-list 5 ./thread_ring_lwt_mvar.bc...    4.876491
# 21      taskset --cpu-list 5 ./crout_decomposition.bc    3.741310
# 22  taskset --cpu-list 5 ./matrix_multiplication.b...   28.847580
# 23  taskset --cpu-list 5 ./evolutionary_algorithm....  131.845247
# 24  taskset --cpu-list 5 ./chameneos_redux_lwt.bc ...    3.236325
# 25        taskset --cpu-list 5 ./quicksort.bc 4000000    1.925361
# 26         taskset --cpu-list 5 ./game_of_life.bc 256   28.378354
# 27             taskset --cpu-list 5 ./knucleotide3.bc   77.724948
# 28             taskset --cpu-list 5 ./test_lwt.bc 200   19.374016
# 29       taskset --cpu-list 5 ./mandelbrot6.bc 16_000  220.872712
# 30          taskset --cpu-list 5 ./levinson_durbin.bc    9.447032
# 31  taskset --cpu-list 5 ./thread_ring_lwt_stream....   14.198545
# 32        taskset --cpu-list 5 ./fannkuchredux2.bc 12  232.729361
# 33                       taskset --cpu-list 5 ./kb.bc    5.695230
# 34    taskset --cpu-list 5 ./LU_decomposition.bc 1024   11.243925
#
#     user_time_secs  sys_time_secs  maxrss_kB  codesize  ocaml_url  \
# 0        12.403690       0.003330      11136       0.0  ../../src
# 1        20.227080       0.009984      25124       0.0  ../../src
# 2        94.839186       0.000000      10284       0.0  ../../src
# 3         1.142495       0.000000       9996       0.0  ../../src
# 4       394.607409       0.006663      10300       0.0  ../../src
# 5         4.285968       0.003329      11832       0.0  ../../src
# 6        33.694022       0.000000      10748       0.0  ../../src
# 7        10.746870       0.006663      10328       0.0  ../../src
# 8         4.239880       0.016666      14308       0.0  ../../src
# 9        60.663032       0.106625     410444       0.0  ../../src
# 10        5.321840       0.006664      21232       0.0  ../../src
# 11        2.592727       0.069975     216420       0.0  ../../src
# 12       10.028050       0.003333      25800       0.0  ../../src
# 13        6.314187       0.013327     217828       0.0  ../../src
# 14       15.492906       0.000000      20232       0.0  ../../src
# 15        2.881763       0.003332       9896       0.0  ../../src
# 16       23.542095       0.006661      25032       0.0  ../../src
# 17        9.701667       0.026658     160160       0.0  ../../src
# 18       37.199980       0.000000      11424       0.0  ../../src
# 19        9.827840       0.046655     212940       0.0  ../../src
# 20        4.868328       0.006663      11972       0.0  ../../src
# 21        3.730032       0.009999      72732       0.0  ../../src
# 22       28.837104       0.003330      33992       0.0  ../../src
# 23      131.328980       0.476515    2815316       0.0  ../../src
# 24        3.078554       0.156593      11216       0.0  ../../src
# 25        1.917889       0.006669      40392       0.0  ../../src
# 26       28.364435       0.006666      25724       0.0  ../../src
# 27       77.626923       0.079971     275060       0.0  ../../src
# 28       19.361369       0.006663      14084       0.0  ../../src
# 29      220.815552       0.000000      10404       0.0  ../../src
# 30        9.437429       0.006663      10680       0.0  ../../src
# 31       14.190824       0.003332      14632       0.0  ../../src
# 32      232.687430       0.003330       8024       0.0  ../../src
# 33        5.689784       0.003332      13424       0.0  ../../src
# 34       11.233972       0.006662      42292       0.0  ../../src
#
#      ocaml.version ocaml.c_compiler  ... gc.allocated_words gc.minor_words  \
# 0   4.11.1+dev_jit              gcc  ...         3908428073     3908412655
# 1   4.11.1+dev_jit              gcc  ...         4761174129     4761149266
# 2   4.11.1+dev_jit              gcc  ...        53000009642    53000005923
# 3   4.11.1+dev_jit              gcc  ...          589329228      589326695
# 4   4.11.1+dev_jit              gcc  ...        10391898334    10391894744
# 5   4.11.1+dev_jit              gcc  ...         2298525753     2298516665
# 6   4.11.1+dev_jit              gcc  ...        12100657183    12100532563
# 7   4.11.1+dev_jit              gcc  ...         2846899927     2846896149
# 8   4.11.1+dev_jit              gcc  ...          179068763      179066013
# 9   4.11.1+dev_jit              gcc  ...         1891491094     1842832767
# 10  4.11.1+dev_jit              gcc  ...          273662001      273398109
# 11  4.11.1+dev_jit              gcc  ...           79174867       79171295
# 12  4.11.1+dev_jit              gcc  ...         1473444329     1472909943
# 13  4.11.1+dev_jit              gcc  ...         1980761237     1975517969
# 14  4.11.1+dev_jit              gcc  ...         1157354718     1051653823
# 15  4.11.1+dev_jit              gcc  ...         1051029019     1051026807
# 16  4.11.1+dev_jit              gcc  ...         6441133781     6441108918
# 17  4.11.1+dev_jit              gcc  ...          916464223      916460553
# 18  4.11.1+dev_jit              gcc  ...        14497763104    14497757847
# 19  4.11.1+dev_jit              gcc  ...         2478192301     2452771892
# 20  4.11.1+dev_jit              gcc  ...         1146881274     1146875403
# 21  4.11.1+dev_jit              gcc  ...         1090016633     1082482474
# 22  4.11.1+dev_jit              gcc  ...            5255381        2102795
# 23  4.11.1+dev_jit              gcc  ...        17029595390    15729333249
# 24  4.11.1+dev_jit              gcc  ...          688825506      688820417
# 25  4.11.1+dev_jit              gcc  ...            9420864        5420155
# 26  4.11.1+dev_jit              gcc  ...           24120699       22018738
# 27  4.11.1+dev_jit              gcc  ...          104935419       72532419
# 28  4.11.1+dev_jit              gcc  ...         1114181556     1097727234
# 29  4.11.1+dev_jit              gcc  ...       103041862887   103041859280
# 30  4.11.1+dev_jit              gcc  ...         4959045313     4709007396
# 31  4.11.1+dev_jit              gcc  ...         2313866071     2313860027
# 32  4.11.1+dev_jit              gcc  ...               8192           4602
# 33  4.11.1+dev_jit              gcc  ...          631259336      631256600
# 34  4.11.1+dev_jit              gcc  ...         2883235061     2879040030
#
#    gc.promoted_words gc.major_words gc.minor_collections  \
# 0            3244647        3260065                15000
# 1             792163         817026                18166
# 2            1715362        1719081               202385
# 3             319152         321685                 2287
# 4              83377          86967                39652
# 5            2833311        2842399                 8788
# 6             373948         498568                46210
# 7              32663          36441                10864
# 8           24540970       24543720                  765
# 9            2684306       51342633                 7036
# 10           6135537        6399429                 1292
# 11          49765463       49769035                  310
# 12           1936149        2470535                 5624
# 13         135288833      140532101                 7564
# 14            153194      105854089                 4294
# 15            144112         146324                 4041
# 16            905621         930484                24576
# 17         266446728      266450398                 3528
# 18           5905726        5910983                55389
# 19             26532       25446941                 9361
# 20         118963458      118969329                 5251
# 21            344277        7878436                 4151
# 22              1537        3154123                   16
# 23           1185242     1301447383                60026
# 24           1113138        1118227                 2684
# 25              1528        4002237                   22
# 26              1712        2103673                   91
# 27           1678748       34081748                  282
# 28          10981773       27436095                 4374
# 29           8824476        8828083               394122
# 30            180420      250218337                20613
# 31         579777060      579783104                10299
# 32                 0           3590                    0
# 33          25859621       25862357                 2526
# 34             39921        4234952                11003
#
#     gc.major_collections  gc.heap_words  gc.heap_chunks  gc.top_heap_words  \
# 0                    183         126976               1             126976
# 1                      8         661504               9             661504
# 2                    415          61440               1             188416
# 3                     80          61440               1             188416
# 4                     23          61440               1             188416
# 5                     45         311296               4             311296
# 6                    120         126976               1             126976
# 7                      9          61440               1             188416
# 8                    233         568832               9             568832
# 9                     12       87480320              11           87480320
# 10                    21        1531904              15            1531904
# 11                    18       25093632              35           25093632
# 12                    10        2093568              14            2093568
# 13                    30       25499648              19           25499648
# 14                   787         674816               8             843776
# 15                    66          61440               1             188416
# 16                    10         661504               9             661504
# 17                    66       18974208              33           18974208
# 18                   169         126976               1             126976
# 19                     9       45877760               3           45877760
# 20                  1749         188416               2             188416
# 21                     9        8202240              27            8202240
# 22                     5        3545600              21            3545600
# 23                    33      357150208              54          357150208
# 24                   115          61440               1             188416
# 25                     1        7327232               2            7327232
# 26                     5        2330624              18            2330624
# 27                     5       57502208               3           57502208
# 28                   374         249856               3             249856
# 29                  2099          61440               1             188416
# 30                  5417         245760               4             249856
# 31                  4411         499712               7             499712
# 32                     0         126976               1             126976
# 33                   329         307200               5             499712
# 34                    39        7677952               5            7677952
#
#     gc.compactions
# 0                0
# 1                0
# 2                2
# 3                2
# 4                2
# 5                0
# 6                0
# 7                2
# 8               23
# 9                0
# 10               0
# 11               0
# 12               0
# 13               0
# 14              64
# 15               2
# 16               0
# 17               0
# 18               0
# 19               0
# 20               0
# 21               0
# 22               0
# 23               0
# 24               2
# 25               0
# 26               0
# 27               0
# 28               0
# 29               2
# 30               4
# 31               0
# 32               0
# 33               6
# 34               0
#
# [35 rows x 25 columns]

# %%
jit.sort_values(by='time_secs', ascending=False)
# Out:
#                                          name  \
# 4                            fannkuchredux.12
# 36                          fannkuchredux2.12
# 33                         mandelbrot6.16_000
# 26         evolutionary_algorithm.10000_10000
# 2                            nbody.50_000_000
# 31                              knucleotide3.
# 10                               knucleotide.
# 6                         spectralnorm2.5_500
# 19                               lexifi-g2pp.
# 25                 matrix_multiplication.1024
# 30                           game_of_life.256
# 17  imrin_mem_rw.10_000_50_000_80_100_000_000
# 32                               test_lwt.200
# 1   imrin_mem_rw.10_000_50_000_20_100_000_000
# 15                 test_decompress.64_524_288
# 35              thread_ring_lwt_stream.20_000
# 13                                     bdd.26
# 20                          fasta6.25_000_000
# 7                           fasta3.25_000_000
# 18                            binarytrees5.21
# 0                           naive-multilayer.
# 34                           levinson-durbin.
# 38                      LU_decomposition.1024
# 8                                regexredux2.
# 14                                       fft.
# 11                         floyd_warshall.512
# 22                thread_ring_lwt_mvar.20_000
# 5                           qr-decomposition.
# 37                                        kb.
# 9                                  kb_no_exc.
# 12                                  revcomp2.
# 24                       crout-decomposition.
# 27                 chameneos_redux_lwt.600000
# 16                         sequence_cps.10000
# 21                           pidigits5.10_000
# 29                          quicksort.4000000
# 3                       durand-kerner-aberth.
# 28                             zarith_pi.5000
# 23                   yojson_ydump.sample.json
#
#                                               command   time_secs  \
# 4          taskset --cpu-list 5 ./fannkuchredux.bc 12  379.488397
# 36        taskset --cpu-list 5 ./fannkuchredux2.bc 12  328.105117
# 33       taskset --cpu-list 5 ./mandelbrot6.bc 16_000  207.662356
# 26  taskset --cpu-list 5 ./evolutionary_algorithm....  145.109579
# 2          taskset --cpu-list 5 ./nbody.bc 50_000_000   88.224394
# 31             taskset --cpu-list 5 ./knucleotide3.bc   74.114721
# 10              taskset --cpu-list 5 ./knucleotide.bc   70.959650
# 6       taskset --cpu-list 5 ./spectralnorm2.bc 5_500   33.674721
# 19                     taskset --cpu-list 5 ./main.bc   33.095634
# 25  taskset --cpu-list 5 ./matrix_multiplication.b...   29.249789
# 30         taskset --cpu-list 5 ./game_of_life.bc 256   23.836251
# 17  taskset --cpu-list 5 ./irmin_mem_rw.bc 10_000 ...   23.716842
# 32             taskset --cpu-list 5 ./test_lwt.bc 200   20.191331
# 1   taskset --cpu-list 5 ./irmin_mem_rw.bc 10_000 ...   19.795780
# 15  taskset --cpu-list 5 ./test_decompress.bc 64 5...   14.678336
# 35  taskset --cpu-list 5 ./thread_ring_lwt_stream....   13.762132
# 13                   taskset --cpu-list 5 ./bdd.bc 26   12.689203
# 20        taskset --cpu-list 5 ./fasta6.bc 25_000_000   11.738926
# 7         taskset --cpu-list 5 ./fasta3.bc 25_000_000   11.366368
# 18          taskset --cpu-list 5 ./binarytrees5.bc 21   11.249499
# 0          taskset --cpu-list 5 ./naive_multilayer.bc   10.632680
# 34          taskset --cpu-list 5 ./levinson_durbin.bc    9.622498
# 38    taskset --cpu-list 5 ./LU_decomposition.bc 1024    9.553678
# 8               taskset --cpu-list 5 ./regexredux2.bc    9.353625
# 14                      taskset --cpu-list 5 ./fft.bc    6.901376
# 11       taskset --cpu-list 5 ./floyd_warshall.bc 512    5.730140
# 22  taskset --cpu-list 5 ./thread_ring_lwt_mvar.bc...    5.343317
# 5          taskset --cpu-list 5 ./qr_decomposition.bc    4.901057
# 37                       taskset --cpu-list 5 ./kb.bc    4.817259
# 9                 taskset --cpu-list 5 ./kb_no_exc.bc    3.572056
# 12                 taskset --cpu-list 5 ./revcomp2.bc    3.373420
# 24      taskset --cpu-list 5 ./crout_decomposition.bc    3.286668
# 27  taskset --cpu-list 5 ./chameneos_redux_lwt.bc ...    3.099997
# 16       taskset --cpu-list 5 ./sequence_cps.bc 10000    3.046677
# 21         taskset --cpu-list 5 ./pidigits5.bc 10_000    2.544595
# 29        taskset --cpu-list 5 ./quicksort.bc 4000000    2.316454
# 3      taskset --cpu-list 5 ./durand_kerner_aberth.bc    1.304301
# 28           taskset --cpu-list 5 ./zarith_pi.bc 5000    0.634778
# 23     taskset --cpu-list 5 ./ydump.bc -c sample.json    0.569438
#
#     user_time_secs  sys_time_secs  maxrss_kB  codesize  ocaml_url  \
# 4       379.388943       0.000000       8000       0.0  ../../src
# 36      328.043837       0.003333       7420       0.0  ../../src
# 33      207.597638       0.006664       8004       0.0  ../../src
# 26      144.635133       0.429844    2812704       0.0  ../../src
# 2        88.199872       0.000000       8036       0.0  ../../src
# 31       74.009168       0.086635     272924       0.0  ../../src
# 10       70.852271       0.086632     408892       0.0  ../../src
# 6        33.654935       0.009996       8384       0.0  ../../src
# 19       33.078963       0.003333       7856       0.0  ../../src
# 25       29.232033       0.009997      30992       0.0  ../../src
# 30       23.826311       0.003332      22816       0.0  ../../src
# 17       23.703533       0.006665      25184       0.0  ../../src
# 32       20.181002       0.003332      10856       0.0  ../../src
# 1        19.786855       0.003331      25096       0.0  ../../src
# 15       14.673020       0.000000      14312       0.0  ../../src
# 35       13.753988       0.003331      11284       0.0  ../../src
# 13       12.681722       0.003331      22896       0.0  ../../src
# 20       11.691567       0.043326     210276       0.0  ../../src
# 7        11.356320       0.006667       7680       0.0  ../../src
# 18       11.209129       0.036649     157816       0.0  ../../src
# 0        10.618999       0.009994       7904       0.0  ../../src
# 34        9.619297       0.000000       7832       0.0  ../../src
# 38        9.543578       0.006665      39608       0.0  ../../src
# 8         9.097152       0.253221    1217444       0.0  ../../src
# 14        6.855462       0.043324     215080       0.0  ../../src
# 11        5.714820       0.013328      18228       0.0  ../../src
# 22        5.341431       0.000000       9240       0.0  ../../src
# 5         4.892762       0.006662       9024       0.0  ../../src
# 37        4.811821       0.003332      10536       0.0  ../../src
# 9         3.560516       0.010002      10832       0.0  ../../src
# 12        3.332047       0.039980     213324       0.0  ../../src
# 24        3.272093       0.013339      69872       0.0  ../../src
# 27        2.971890       0.126747       9312       0.0  ../../src
# 16        3.042183       0.003333       6796       0.0  ../../src
# 21        1.389629       1.153092      23220       0.0  ../../src
# 29        2.312274       0.003331      37812       0.0  ../../src
# 3         1.298417       0.003330       7388       0.0  ../../src
# 28        0.343771       0.290374      21048       0.0  ../../src
# 23        0.562232       0.006691      14808       0.0  ../../src
#
#      ocaml.version ocaml.c_compiler  ... gc.allocated_words gc.minor_words  \
# 4   4.11.1+dev_jit              gcc  ...        10391898334    10391894744
# 36  4.11.1+dev_jit              gcc  ...               8192           4602
# 33  4.11.1+dev_jit              gcc  ...       103041862887   103041859280
# 26  4.11.1+dev_jit              gcc  ...        17030891906    15730629765
# 2   4.11.1+dev_jit              gcc  ...        53000009642    53000005923
# 31  4.11.1+dev_jit              gcc  ...          104935419       72532419
# 10  4.11.1+dev_jit              gcc  ...         1891491094     1842832767
# 6   4.11.1+dev_jit              gcc  ...        12100657183    12100532563
# 19  4.11.1+dev_jit              gcc  ...        14497763104    14497757847
# 25  4.11.1+dev_jit              gcc  ...            5255381        2102795
# 30  4.11.1+dev_jit              gcc  ...           24120699       22018738
# 17  4.11.1+dev_jit              gcc  ...         6441133781     6441108918
# 32  4.11.1+dev_jit              gcc  ...         1114181556     1097727234
# 1   4.11.1+dev_jit              gcc  ...         4761174129     4761149266
# 15  4.11.1+dev_jit              gcc  ...         1157354718     1051653823
# 35  4.11.1+dev_jit              gcc  ...         2313866071     2313860027
# 13  4.11.1+dev_jit              gcc  ...         1473444329     1472909943
# 20  4.11.1+dev_jit              gcc  ...         2478192301     2452771892
# 7   4.11.1+dev_jit              gcc  ...         2846899927     2846896149
# 18  4.11.1+dev_jit              gcc  ...          916464223      916460553
# 0   4.11.1+dev_jit              gcc  ...         3908428073     3908412655
# 34  4.11.1+dev_jit              gcc  ...         4959045313     4709007396
# 38  4.11.1+dev_jit              gcc  ...         2883235061     2879040030
# 8   4.11.1+dev_jit              gcc  ...          288711833      216267142
# 14  4.11.1+dev_jit              gcc  ...         1980761237     1975517969
# 11  4.11.1+dev_jit              gcc  ...          273662001      273398109
# 22  4.11.1+dev_jit              gcc  ...         1146881274     1146875403
# 5   4.11.1+dev_jit              gcc  ...         2298525753     2298516665
# 37  4.11.1+dev_jit              gcc  ...          631259336      631256600
# 9   4.11.1+dev_jit              gcc  ...          179068763      179066013
# 12  4.11.1+dev_jit              gcc  ...           79174867       79171295
# 24  4.11.1+dev_jit              gcc  ...         1090016633     1082482474
# 27  4.11.1+dev_jit              gcc  ...          688825506      688820417
# 16  4.11.1+dev_jit              gcc  ...         1051029019     1051026807
# 21  4.11.1+dev_jit              gcc  ...         1667836266        3721660
# 29  4.11.1+dev_jit              gcc  ...            9420864        5420155
# 3   4.11.1+dev_jit              gcc  ...          589329228      589326695
# 28  4.11.1+dev_jit              gcc  ...          396131833        3425517
# 23  4.11.1+dev_jit              gcc  ...           12167404        9937912
#
#    gc.promoted_words gc.major_words gc.minor_collections  \
# 4              83377          86967                39652
# 36                 0           3590                    0
# 33           8824476        8828083               394122
# 26           1186201     1301448342                60030
# 2            1715362        1719081               202385
# 31           1678748       34081748                  282
# 10           2684306       51342633                 7036
# 6             373948         498568                46210
# 19           6104446        6109703                55392
# 25              1537        3154123                   16
# 30              1712        2103673                   91
# 17            907422         932285                24576
# 32          11034561       27488883                 4374
# 1             792477         817340                18166
# 15            154460      105855355                 4299
# 35         580196438      580202482                10299
# 13           1936149        2470535                 5624
# 20             23358       25443767                 9361
# 7              29545          33323                10863
# 18         266508144      266511814                 3526
# 0            3278991        3294409                15001
# 34            171889      250209806                20614
# 38             39913        4234944                11003
# 8          167966807      240411498                  848
# 14         135288833      140532101                 7564
# 11           6135537        6399429                 1292
# 22         118963458      118969329                 5251
# 5            2833275        2842363                 8788
# 37          26113997       26116733                 2527
# 9           24031137       24033887                  763
# 12          49848350       49851922                  310
# 24            341718        7875877                 4152
# 27           1204385        1209474                 2688
# 16            173096         175308                 4048
# 21             34723     1664149329                 4490
# 29              1528        4002237                   22
# 3             319191         321724                 2287
# 28             20904      392727220                 1075
# 23           1804767        4034259                   44
#
#     gc.major_collections  gc.heap_words  gc.heap_chunks  gc.top_heap_words  \
# 4                     23          61440               1             188416
# 36                     0         126976               1             126976
# 33                  2099          61440               1             188416
# 26                    31      357150208              54          357150208
# 2                    415          61440               1             188416
# 31                     5       57502208               3           57502208
# 10                    12       87480320              11           87480320
# 6                    120         126976               1             126976
# 19                   175         126976               1             126976
# 25                     5        3545600              21            3545600
# 30                     5        2330624              18            2330624
# 17                    10         661504               9             661504
# 32                   374         249856               3             249856
# 1                      8         661504               9             661504
# 15                   800         661504               8             843776
# 35                  4412         434176               6             434176
# 13                    10        2093568              14            2093568
# 20                     9       45877760               3           45877760
# 7                      8          61440               1             188416
# 18                    61       18974208              33           18974208
# 0                    184         126976               1             126976
# 34                  5411         245760               4             249856
# 38                    39        7677952               5            7677952
# 8                     25      151633920              19          151633920
# 14                    30       25499648              19           25499648
# 11                    21        1531904              15            1531904
# 22                  1749         188416               2             188416
# 5                     43         311296               4             311296
# 37                   330         430080               7             499712
# 9                    229         494592               8             568832
# 12                    18       25093632              35           25093632
# 24                     9        8202240              27            8202240
# 27                   122          61440               1             188416
# 16                    79          61440               1             188416
# 21                  2688        1515008              16            2003968
# 29                     1        7327232               2            7327232
# 3                     79          61440               1             188416
# 28                   640        1317376              15            1761792
# 23                    17         568832               9             752640
#
#     gc.compactions
# 4                2
# 36               0
# 33               2
# 26               0
# 2                2
# 31               0
# 10               0
# 6                0
# 19               0
# 25               0
# 30               0
# 17               0
# 32               0
# 1                0
# 15              62
# 35               0
# 13               0
# 20               0
# 7                2
# 18               0
# 0                0
# 34               4
# 38               0
# 8                0
# 14               0
# 11               0
# 22               0
# 5                0
# 37               7
# 9               15
# 12               0
# 24               0
# 27               2
# 16               2
# 21             895
# 29               0
# 3                2
# 28             212
# 23               5
#
# [39 rows x 25 columns]

# %%
def add_suffix(df, suffix):
    return df.add_suffix(suffix).rename(columns={f'name{suffix}': 'name'})

combined = (
    add_suffix(cranelift, '_cranelift')
    #.merge(add_suffix(stock, '_stock'), on='name')
#    .merge(add_suffix(jit_disabled, '_jit_disabled'), on='name')
#    .merge(add_suffix(compile_only, '_compile_only'), on='name')
    .merge(add_suffix(jit, '_jit'), on='name')
)[['name', 'time_secs_jit', 'time_secs_cranelift']] #  'time_secs_jit_disabled', 'time_secs_compile_only', 
combined['speedup'] = combined.time_secs_jit / combined.time_secs_cranelift
combined = combined.sort_values(by='speedup', ascending=False).reset_index(drop=True)
print(combined.to_string())
# Out:
#                                          name  time_secs_jit  time_secs_cranelift   speedup
# 0                           fannkuchredux2.12     331.788337           232.729361  1.425640
# 1                             binarytrees5.21      12.753560             9.731460  1.310549
# 2                                   revcomp2.       3.451768             2.663806  1.295803
# 3                                      bdd.26      12.902045            10.034514  1.285767
# 4                           quicksort.4000000       2.396741             1.925361  1.244827
# 5                           fasta6.25_000_000      12.013376             9.877710  1.216211
# 6                           qr-decomposition.       5.215481             4.290923  1.215468
# 7                                knucleotide.      73.199312            60.786151  1.204210
# 8          evolutionary_algorithm.10000_10000     157.800842           131.845247  1.196864
# 9                 thread_ring_lwt_mvar.20_000       5.545291             4.876491  1.137148
# 10                               lexifi-g2pp.      42.115606            37.212973  1.131745
# 11                         sequence_cps.10000       3.244004             2.886088  1.124014
# 12                        spectralnorm2.5_500      36.839984            33.703385  1.093065
# 13                          fasta3.25_000_000      11.679121            10.756673  1.085756
# 14                           levinson-durbin.      10.122383             9.447032  1.071488
# 15                               test_lwt.200      20.410570            19.374016  1.053502
# 16                         floyd_warshall.512       5.544874             5.330353  1.040245
# 17  imrin_mem_rw.10_000_50_000_80_100_000_000      24.437631            23.554973  1.037472
# 18                              knucleotide3.      80.423783            77.724948  1.034723
# 19                                       fft.       6.433711             6.329975  1.016388
# 20              thread_ring_lwt_stream.20_000      14.391681            14.198545  1.013603
# 21                 matrix_multiplication.1024      29.227715            28.847580  1.013177
# 22  imrin_mem_rw.10_000_50_000_20_100_000_000      20.373799            20.242394  1.006492
# 23                           fannkuchredux.12     393.386720           394.706636  0.996656
# 24                         mandelbrot6.16_000     219.429050           220.872712  0.993464
# 25                 chameneos_redux_lwt.600000       3.149153             3.236325  0.973065
# 26                 test_decompress.64_524_288      15.017373            15.497876  0.968996
# 27                      durand-kerner-aberth.       1.076851             1.143021  0.942110
# 28                           nbody.50_000_000      89.094228            94.862960  0.939189
# 29                          naive-multilayer.      11.341957            12.410587  0.913894
# 30                       crout-decomposition.       3.379583             3.741310  0.903315
# 31                      LU_decomposition.1024      10.031759            11.243925  0.892194
# 32                                        kb.       5.007410             5.695230  0.879229
# 33                                 kb_no_exc.       3.728638             4.258226  0.875632
# 34                           game_of_life.256      23.945203            28.378354  0.843784

# %%
combined['speedup_jit_stock'].mean()
# Out:
# 1.346423291055871
